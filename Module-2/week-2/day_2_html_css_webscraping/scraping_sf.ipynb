# %% [markdown]
# # Python Web Scraping Tutorial using BeautifulSoup

# %% [markdown]
# ## Recap: APIs

# %%
import requests
url = 'https://venmo.com/api/v5/public'
resp = requests.get(url)

assert(resp.status_code == 200)

# to check the code returns the error code 
# assert resp.status_code == 400, "error code!!!


content = resp.json()

# %%
content.keys()
# Out:
# dict_keys(['paging', 'data'])

# %%
len(content.get('data'))
# Out:
# 20

# %% [markdown]
# use a .get() method if you are retriving information form url

# %%
print(content.get('data')[0].keys())
# Out:
# dict_keys(['payment_id', 'permalink', 'via', 'action_links', 'transactions', 'story_id', 'comments', 'updated_time', 'audience', 'actor', 'created_time', 'mentions', 'message', 'type', 'likes'])

# %%
print(*[x['message'] for x in content.get('data')], sep='\n')
# Out:
# Taste
# Ono 🔥
# 53.8 + 15.55 + 16.55 🕺
# Here ya go
# wifi baby
# food
# 🎟
# Resource home show acct
# Drugs
# 👕
# Rent
# 🌻🌻🌻🌻🌻
# 🍪🍪🍪
# ⛽️ 🏖
# For bills on Splitwise.com
# 🐶
# 🤖👽👻
# 🌹
# ⚡🔌💡💸
# Fooooood

# %% [markdown]
# ## The components of a web page

# %% [markdown]
# When we visit a web page, our web browser makes a GET request to a web server. The server then sends back files that tell our browser how to render the page for us. The files fall into a few main types:
#
# - HTML — contain the main content of the page.
# - CSS — add styling to make the page look nicer.
# - JS — Javascript files add interactivity to web pages.
# - Images — image formats, such as JPG and PNG allow web pages to show pictures.
#
# After our browser receives all the files, it renders the page and displays it to us. There’s a lot that happens behind the scenes to render a page nicely, but we don’t need to worry about most of it when we’re web scraping.

# %% [markdown]
# ### HTML
#
#
# HyperText Markup Language (HTML) is a language that web pages are created in. HTML isn’t a programming language, like Python — instead, it’s a markup language that tells a browser how to layout content.
#
# Let’s take a quick tour through HTML so we know enough to scrape effectively. HTML consists of elements called tags. The most basic tag is the `<html>` tag. This tag tells the web browser that everything inside of it is HTML. We can make a simple HTML document just using this tag:
#
# ~~~
# <html>
# </html>
# ~~~
# &#x2B07; Example cell with html in Markdown!

# %% [markdown]
# <html>
# </html>

# %% [markdown]
# Right inside an html tag, we put two other tags, the head tag, and the body tag. The main content of the web page goes into the body tag. The head tag contains data about the title of the page, and other information that generally isn’t useful in web scraping:
#
# ~~~
# <html>
#     <head>
#     </head>
#     <body>
#     </body>
# </html>
# ~~~

# %% [markdown]
# We’ll now add our first content to the page, in the form of the p tag. The p tag defines a paragraph, and any text inside the tag is shown as a separate paragraph:
# ~~~
# <html>
#     <head>
#     </head>
#     <body>
#           <p>
#             Here's a paragraph of text!
#         </p>
#         <p>
#             Here's a second paragraph of text!
#         </p>
#     </body>
# </html>
# ~~~

# %% [markdown]
# <html>
#     <head>
#     </head>
#     <body>
#           <p>
#             Here's a paragraph of text!
#         </p>
#         <p>
#             Here's a second paragraph of text!
#         </p>
#     </body>
# </html>

# %% [markdown]
# Tags have commonly used names that depend on their position in relation to other tags:
#
# - **child** — a child is a tag inside another tag. So the two p tags above are both children of the body tag.
# - **parent** — a parent is the tag another tag is inside. Above, the html tag is the parent of the body tag.
# - **sibiling** — a sibiling is a tag that is nested inside the same parent as another tag. For example, head and body are siblings, since they’re both inside html. Both p tags are siblings, since they’re both inside body.

# %% [markdown]
# We can also add properties to HTML tags that change their behavior:
#
# ~~~
# <html>
#   <head></head>
#   <body>
#     <p>
#       Here's a paragraph of text!
#       <a href="https://www.dataquest.io">Learn Data Science Online</a>
#     </p>
#     <p>
#       Here's a second paragraph of text!
#       <a href="https://www.python.org">Python</a>
#     </p>
#   </body>
# </html>
# ~~~

# %% [markdown]
# <html>
#     <head>
#     </head>
#     <body>
#         <p>
#             Here's a paragraph of text!
#             <a href="https://www.dataquest.io">Learn Data Science Online</a>
#         </p>
#         <p>
#             Here's a second paragraph of text!
#             <a href="https://www.python.org">Python</a>        </p>
#     </body></html>

# %% [markdown]
# In the above example, we added two a tags. a tags are links, and tell the browser to render a link to another web page. The href property of the tag determines where the link goes.
#
# a and p are extremely common html tags. Here are a few others:
#
# - *div* — indicates a division, or area, of the page.
# - *b* — bolds any text inside.
# - *i* — italicizes any text inside.
# - *table* — creates a table.
# - *form* — creates an input form.
#
#
# For a full list of tags, look [here](https://developer.mozilla.org/en-US/docs/Web/HTML/Element).

# %% [markdown]
# There are two special properties give HTML elements names, and make them easier to interact with when we’re scraping, **class** and **id** properties.
#
# - One element can have multiple classes, and a class can be shared between elements.
# - Each element can only have one id, and an id can only be used once on a page.
# - Classes and ids are optional, and not all elements will have them.
#
# We can add classes and ids to our example:
#
# ~~~
# <html>
#     <head>
#     </head>
#     <body>
#         <p class="bold-paragraph">
#             Here's a paragraph of text!
#             <a href="https://www.dataquest.io" id="learn-link">Learn Data Science Online</a>
#         </p>
#         <p class="bold-paragraph extra-large">
#             Here's a second paragraph of text!
#             <a href="https://www.python.org" class="extra-large">Python</a>
#         </p>
#     </body>
# </html>
# ~~~

# %% [markdown]
# **class = "bold-paragraph extra-large" are two different class and they are usually separeted by space**

# %% [markdown]
# <html>
#     <head>
#     </head>
#     <body>
#         <p class="bold-paragraph">
#             Here's a paragraph of text!
#             <a href="https://www.dataquest.io" id="learn-link">Learn Data Science Online</a>
#         </p>
#         <p class="bold-paragraph extra-large">
#             Here's a second paragraph of text!
#             <a href="https://www.python.org" class="extra-large">Python</a>
#         </p>
#     </body>
# </html>

# %% [markdown]
# ## Apply this knowledge
#
# Let's go to a webpage and change some of the HTML to see what happens.
#
# - Open up a webpage in Chrome.
# - Right click and 'inspect element.
#
# - Change the text in a tag.
# - Change the class of a tag.
# - Find a tag with an ID and remove it.

# %% [markdown]
# ## Webscraping with Python

# %% [markdown]
# ### The requests library
# The first thing we’ll need to do to scrape a web page is to download the page. We can download pages using the Python requests library (similar to interacting with APIs!).

# %%
import requests
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")
page
# Out:
# <Response [200]>

# %% [markdown]
# After running our request, we get a Response object. This object has a status_code property, which indicates if the page was downloaded successfully:

# %%
page.status_code
# Out:
# 200

# %% [markdown]
# We can print out the HTML content of the page using the content property:

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'

# %%
print(page.text)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>A simple example page</title>
#     </head>
#     <body>
#         <p>Here is some simple content for this page.</p>
#     </body>
# </html>

# %%
# this is not a json file. so it throws an error
page1 = page.json()
page1
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-17-fe4e8e0bfce5> in <module>
# ----> 1 page1 = page.json()
#       2 page1
#
# /anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
# ...

# %% [markdown]
# ### Parsing a page with BeautifulSoup
#
# We can use the BeautifulSoup library to parse this document, and extract the text from the `<p>` tag.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %% [markdown]
# As all the tags are nested, we can move through the structure one level at a time. We can first select all the elements at the top level of the page using the `children` property of `soup`.

# %%
list(soup.children)
# len(list(soup.children)) # two childrens
# Out:
# ['html', <html>
#  <head>
#  <title>A simple example page</title>
#  </head>
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>
#  </html>]

# %% [markdown]
# The above tells us that there are two tags at the top level of the page — the initial `<!DOCTYPE html>` tag, and the `<html>` tag. There is a newline character `(\n)` in the list as well. Let’s see what the type of each element in the list is:

# %%
[type(item) for item in list(soup.children)]
# the list is a doctype and a tag
# Out:
# [bs4.element.Doctype, bs4.element.Tag]

# %% [markdown]
# The `Tag` object allows us to navigate through an HTML document, and extract other tags and text. You can learn more about the various `BeautifulSoup` objects [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-objects).
#
# We can now select the html tag and its children by taking the second item in the list:

# %%
html = list(soup.children)[1]
html
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
print(soup.prettify())#.children)[1]
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
html = list(soup.children)[1]
body = list(html.children)[3]
p = list(body.children)[1]
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# Each item in the list returned by the `children` property is also a `BeautifulSoup` object, so we can also call the `children` method on `html`.
#
# Now, we can find the `children` inside the `html` tag:

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <title>A simple example page</title>
#  </head>, '\n', <body>
#  <p>Here is some simple content for this page.</p>
#  </body>, '\n']

# %% [markdown]
# As you can see above, there are two tags here, `head`, and `body`. We want to extract the text inside the `p` tag, so we’ll dive into the body:

# %%
body = list(html.children)[3]
body
# Out:
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %% [markdown]
# We can now isolate the `p` tag:

# %%
p = list(body.children)[1]
p
# Out:
# <p>Here is some simple content for this page.</p>

# %% [markdown]
# Once we’ve isolated the tag, we can use the `get_text` method to extract all of the text inside the tag:

# %%
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# ### Finding all instances of a tag at once
#
# If we want to extract a single tag, we can instead use the find_all method, which will find all the instances of a tag on a page.

# %%
soup = BeautifulSoup(page.content)
soup.find_all('p')
# Out:
# [<p>Here is some simple content for this page.</p>]

# %%
type(soup.find_all('p'))
# Out:
# bs4.element.ResultSet

# %% [markdown]
# Note that `find_all` returns a list, so we’ll have to loop through, or use list indexing, it to extract text:

# %%
soup.find_all('p')[0].get_text()
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# If you instead only want to find the first instance of a tag, you can use the `find` method, which will return a single `BeautifulSoup` object:

# %%
soup.find('p')
# Out:
# <p>Here is some simple content for this page.</p>

# %% [markdown]
# ### Searching for tags by class and id
#
#
# We introduced classes and ids earlier, but it probably wasn’t clear why they were useful. Classes and ids are used by CSS to determine which HTML elements to apply certain styles to. We can also use them when scraping to specify specific elements we want to scrape. Let's look at the following page:
#
# ~~~
# <html>
#     <head>
#         <title>A simple example page</title>
#     </head>
#     <body>
#         <div>
#             <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>
#             <p class="inner-text">
#                 Second paragraph.
#             </p>
#         </div>
#         <p class="outer-text first-item" id="second">
#             <b>
#                 First outer paragraph.
#             </b>
#         </p>
#         <p class="outer-text">
#             <b>
#                 Second outer paragraph.
#             </b>
#         </p>
#     </body>
# </html>
# ~~~

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/ids_and_classes.html")
soup = BeautifulSoup(page.content)
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     First paragraph.
#    </p>
#    <p class="inner-text">
#     Second paragraph.
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     First outer paragraph.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     Second outer paragraph.
#    </b>
#   </p>
#  </body>
# </html>

# %% [markdown]
# Now, we can use the `find_all` method to search for items by class or by id. In the below example, we’ll search for any `p` tag that has the class `outer-text`:

# %%
soup.find_all('p', class_='outer-text')
# len(soup.find_all('p', class_='outer-text')) # 2 elemnet in the list
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %% [markdown]
# In the below example, we’ll look for any tag that has the class `outer-text`:

# %%
soup.find_all(class_="outer-text")
# len(soup.find_all(class_="outer-text")) # two elements 
"""
for i in soup.find_all(class_="outer-text"):
    print(i, '\n')
"""
print(x for x in soup.find_all(class_='outer-text'), '\n')
# Out:
#   File "<ipython-input-82-5b3adb97f392>", line 7
#     print(x for x in soup.find_all(class_='outer-text'), '\n')
#          ^
# SyntaxError: Generator expression must be parenthesized

# %%
soup.find_all('p', class_="inner-text")
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>, <p class="inner-text">
#                  Second paragraph.
#              </p>]

# %% [markdown]
# We can also search for elements by `id`:

# %%
soup.find_all(id="first")[0]
# Out:
# <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>

# %% [markdown]
# ### Using CSS Selectors
#
#
# You can also search for items using CSS selectors. These selectors are how the CSS language allows developers to specify HTML tags to style. Here are some examples:
#
# - *p a* — finds all a tags inside of a p tag.
# - *body p a* — finds all a tags inside of a p tag inside of a body tag.
# - *html body* — finds all body tags inside of an html tag.
# - *p.outer-text* — finds all p tags with a class of outer-text.
# - *.outer-text* — finds all tags with a class of outer-text.
# - *p#first* — finds all p tags with an id of first.
# - *body p.outer-text* — finds any p tags with a class of outer-text inside of a body tag.

# %% [markdown]
# `BeautifulSoup` objects support searching a page via CSS selectors using the `select` method. We can use CSS selectors to find all the `p` tags in our page that are inside of a `div` like this:

# %%
soup.select("div p")
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>, <p class="inner-text">
#                  Second paragraph.
#              </p>]

# %% [markdown]
# Note that the `select` method above returns a list of `BeautifulSoup` objects, just like `find` and `find_all`.

# %% [markdown]
# ## Your Turn: Downloading weather data

# %% [markdown]
# We now know enough to proceed with extracting information about the local weather from the National Weather Service website. The first step is to find the page we want to scrape. We’ll extract weather information about downtown DC from this [page](http://forecast.weather.gov/MapClick.php?lat=38.8977&lon=-77.0365).

# %% [markdown]
# We can then scroll up in the elements panel to find the “outermost” element that contains all of the text that corresponds to the extended forecasts. In this case, it’s a `div` tag with the id `seven-day-forecast`:

# %% [markdown]
# We now know enough to download the page and start parsing it. Below let's implement the following:
#
# 1. Download the web page containing the forecast.
# 2. Create a `BeautifulSoup` class to parse the page.
# 3. Find the `div` with id `seven-day-forecast`, and assign to `seven_day`
# 4. Inside `seven_day`, find each individual forecast item.
# 5. Extract and print the first forecast item.

# %%
#your code here
resp = requests.get("https://forecast.weather.gov/MapClick.php?lat=38.8977&lon=-77.0365")
assert (resp.status_code == 200) # to check the info we get is 200
print(resp.status_code)
# Out:
# 200

# %% [markdown]
# we got 200. we are good to go!!! To check the content, we can either use resp.content or resp.text

# %%
# import beautifulsoup library
from bs4 import BeautifulSoup
soup = BeautifulSoup(resp.content)
# print(soup.prettify())

# %% [markdown]
# create a new variable called **seven_day** and find the tag with id ***seven-day-forecast***

# %%
seven_day = soup.find(id='seven-day-forecast-list')
list(seven_day)[0]
# Out:
# <li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Tonight<br/><br/></p>
# <p><img alt="Tonight: Partly cloudy, with a low around 73. South wind around 9 mph, with gusts as high as 18 mph. " class="forecast-icon" src="newimages/medium/nsct.png" title="Tonight: Partly cloudy, with a low around 73. South wind around 9 mph, with gusts as high as 18 mph. "/></p><p class="short-desc">Partly Cloudy</p><p class="temp temp-low">Low: 73 °F</p></div></li>

# %%
print(*[x.get_text() for f in seven_day for x in f.find_all(class_='short-desc')], sep='\n')
# Out:
# Partly Cloudy
# ScatteredShowers thenT-stormsLikely
# T-stormsLikely andPatchy Fog
# IsolatedShowers thenScatteredT-storms
# ScatteredT-storms thenScatteredShowers
# ChanceT-storms
# ChanceShowers
# ChanceShowers
# Partly Cloudy

# %% [markdown]
# ### Extracting information from the page
# As you can see, inside the forecast item `tonight` is all the information we want. There are `4` pieces of information we can extract:
#
# - The name of the forecast item — in this case, **Tonight**.
# - The description of the conditions — this is stored in the `title` property of `img`.
# - A short description of the conditions — in this case, **Mostly Clear**.
# - The temperature low — in this case, **49 degrees**.
#
# We’ll extract the name of the forecast item, the short description, and the temperature first, since they’re all similar:

# %% [markdown]
# Now, we can extract the `title` attribute from the `img` tag. To do this, we just treat the `BeautifulSoup` object like a dictionary, and pass in the attribute we want as a key:

# %%
# your code here
soup.find_all('div')
# Out:
# [<div class="container-fluid">
#  <div class="navbar-header">
#  <button class="navbar-toggle collapsed" data-target="#top-nav" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  </button>
#  </div>
#  <div class="collapse navbar-collapse" id="top-nav">
#  <ul class="nav navbar-nav">
#  <li><a href="http://www.weather.gov">HOME</a></li>
# ...

# %% [markdown]
# ### Extracting all the information from the page
# Now that we know how to extract each individual piece of information, we can combine our knowledge with css selectors and list comprehensions to extract everything at once.
#
# In the below code, we:
#
# - Select all items with the class period-name inside an item with the class tombstone-container in seven_day.
# - Use a list comprehension to call the get_text method on each BeautifulSoup object.

# %%
import requests

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-897fbb36e4ee> in <module>
# ----> 1 period_tags = seven_day.select(".tombstone-container .period-name")
#       2 periods = [pt.get_text() for pt in period_tags]
#       3 periods
#
# NameError: name 'seven_day' is not defined

# %% [markdown]
# As you can see above, our technique gets us each of the period names, in order. Now you can apply the same technique to get the other 3 fields:

# %%
<li class="forecast-tombstone">
<div class="tombstone-container">
<p class="period-name">This<br/>Afternoon</p>
<p><img alt="This Afternoon: Scattered showers and thunderstorms, mainly after 5pm.  
Partly sunny, with a high near 91. South wind around 8 mph.  
Chance of precipitation is 30%." class="forecast-icon" src="newimages/medium/scttsra30.png" 
title="This Afternoon: Scattered showers and thunderstorms, mainly after 5pm.  Partly sunny, with a 
high near 91. South wind around 8 mph.  Chance of precipitation is 30%."/></p>
<p class="short-desc">Scattered<br/>T-storms</p>
<p class="temp temp-high">High: 91 °F</p>
</div>
</li>

# %%
short_descs = [sd.get_text()for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]

print(short_descs)
print(temps)
print(descs)
# Out:
# ['ScatteredT-storms', 'ScatteredT-storms thenSlight ChanceShowers', 'Partly Sunnythen T-stormsLikely', 'T-stormsLikely thenChanceShowers', 'Slight ChanceT-storms', 'Partly Cloudy', 'Partly Sunnythen ChanceShowers', 'Mostly Clear', 'Sunny']
# ['High: 91 °F', 'Low: 74 °F', 'High: 91 °F', 'Low: 71 °F', 'High: 91 °F', 'Low: 73 °F', 'High: 89 °F', 'Low: 67 °F', 'High: 87 °F']
# ...

# %%
# Your code here

# %% [markdown]
# ### Combining our data into a Pandas Dataframe
#
# We can now combine the data into a Pandas DataFrame and analyze it.
#
# In order to do this, we’ll call the DataFrame class, and pass in each list of items that we have. We pass them in as part of a dictionary. Each dictionary key will become a column in the DataFrame, and each list will become the values in the column:

# %%
import pandas as pd
weather = pd.DataFrame({
    "period": periods,
    "short_desc": short_descs,
    "temp": temps,
    "desc": descs
})
weather
# Out:
#            period                                  short_desc         temp  \
# 0   ThisAfternoon                           ScatteredT-storms  High: 91 °F
# 1         Tonight  ScatteredT-storms thenSlight ChanceShowers   Low: 74 °F
# 2       Wednesday             Partly Sunnythen T-stormsLikely  High: 91 °F
# 3  WednesdayNight            T-stormsLikely thenChanceShowers   Low: 71 °F
# 4        Thursday                       Slight ChanceT-storms  High: 91 °F
# 5   ThursdayNight                               Partly Cloudy   Low: 73 °F
# 6          Friday              Partly Sunnythen ChanceShowers  High: 89 °F
# 7     FridayNight                                Mostly Clear   Low: 67 °F
# 8        Saturday                                       Sunny  High: 87 °F
#
#                                                 desc
# 0  This Afternoon: Scattered showers and thunders...
# 1  Tonight: Scattered showers and thunderstorms b...
# 2  Wednesday: Showers and thunderstorms likely, m...
# ...

# %% [markdown]
# We can now do some analysis on the data. For example, we can use a regular expression and the Series.str.extract method to pull out the numeric temperature values:

# %%
'91 ~f'.str.extract('(?P<temp_num>\dt)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-c5070f2d1f19> in <module>
# ----> 1 '91 ~f'.str.extract('(?P<temp_num>\dt)')
#
# AttributeError: 'str' object has no attribute 'str'

# %%
temp_nums = weather["temp"].str.extract("(?P<temp_num>\d+)", expand=False)
weather["temp_num"] = temp_nums.astype('int')
temp_nums
# Out:
# 0    91
# 1    74
# 2    91
# 3    71
# 4    91
# 5    73
# 6    89
# 7    67
# 8    87
# Name: temp_num, dtype: object

# %%
weather['temp'][0]
# Out:
# 'High: 91 °F'

# %% [markdown]
# We could then find the mean of all the high and low temperatures:

# %%
weather["temp_num"].mean()
# Out:
# 81.55555555555556

# %% [markdown]
# We could also only select the rows that happen at night:

# %%
is_night = weather["temp"].str.contains("Low")
weather["is_night"] = is_night
is_night
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# Name: temp, dtype: bool

# %%
weather[is_night]
# Out:
#            period                                  short_desc        temp  \
# 1         Tonight  ScatteredT-storms thenSlight ChanceShowers  Low: 74 °F
# 3  WednesdayNight            T-stormsLikely thenChanceShowers  Low: 71 °F
# 5   ThursdayNight                               Partly Cloudy  Low: 73 °F
# 7     FridayNight                                Mostly Clear  Low: 67 °F
#
#                                                 desc  temp_num  is_night
# 1  Tonight: Scattered showers and thunderstorms b...        74      True
# 3  Wednesday Night: Showers and thunderstorms lik...        71      True
# 5  Thursday Night: Partly cloudy, with a low arou...        73      True
# 7  Friday Night: Mostly clear, with a low around 67.        67      True

# %% [markdown]
# # This is my example code.....

# %%
import requests
url = "https://forecast.weather.gov/MapClick.php?lat=38.8977&lon=-77.0365"
resp = requests.get(url)
assert (resp.status_code == 200) # to check the info we get is 200
print(resp.status_code)
resp.status_code == requests.codes.ok
# Out:
# 200
# True

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(resp.content)
seven_day = soup.find(id='seven-day-forecast-list')
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
short_descs = [sd.get_text()for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]

# %%
import pandas as pd
weather = pd.DataFrame({
    "period": periods,
    "short_desc": short_descs,
    "temp": temps,
    "desc": descs
})
weather
# Out:
#            period                                  short_desc         temp  \
# 0         Tonight  ScatteredT-storms thenSlight ChanceShowers   Low: 74 °F
# 1       Wednesday             Mostly Sunnythen T-stormsLikely  High: 91 °F
# 2  WednesdayNight            T-stormsLikely thenChanceShowers   Low: 71 °F
# 3        Thursday                       Slight ChanceT-storms  High: 90 °F
# 4   ThursdayNight                               Partly Cloudy   Low: 73 °F
# 5          Friday                              ChanceT-storms  High: 89 °F
# 6     FridayNight                                Mostly Clear   Low: 67 °F
# 7        Saturday                                       Sunny  High: 87 °F
# 8   SaturdayNight                                Mostly Clear   Low: 68 °F
#
#                                                 desc
# 0  Tonight: Scattered showers and thunderstorms b...
# 1  Wednesday: Showers and thunderstorms likely, m...
# 2  Wednesday Night: Showers and thunderstorms lik...
# ...

# %% [markdown]
# # user agent

# %%
import pandas as pd

# %%
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.87 Safari/537.36
'}
resp = requests.get('https://www.the-numbers.com/movie/budgets/all', headers=headers)
pd.read_html(resp.content)
# Out:
#   File "<ipython-input-12-3e30afd611e0>", line 1
#     headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.87 Safari/537.36
#                                                                                                                                                       ^
# SyntaxError: EOL while scanning string literal
